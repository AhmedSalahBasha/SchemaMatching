# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from difflib import SequenceMatcher

import numpy,datetime,re
import pandas as pd
import numpy as np

# %%
#READ DATA:
IMDB_DF = pd.read_csv("imdb.csv")
IMDB_DF_SAMPLE = IMDB_DF.sample(5).astype(str)
imdb_header = list(IMDB_DF.columns.values)

#imdb_header
tbl1 = np.array(imdb_header)

ROTTEN_TOMATOES_DF = pd.read_csv("rotten_tomatoes.csv")
ROTTEN_TOMATOES_DF_SAMPLE = ROTTEN_TOMATOES_DF.sample(5).astype(str)
rt_header = list(ROTTEN_TOMATOES_DF.columns.values)
#rt_header
tbl2 = np.array(rt_header)

# %%
#creation array to add sort index of matching
# For matching
Pref=np.zeros((len(tbl1)+1,len(tbl2)+1))
#for Tomatoes
pref_tom=np.zeros((len(tbl1),len(tbl2)),dtype=np.int8)
ipref_tom=np.zeros((len(tbl1),len(tbl2)),dtype=np.int8)
#for IMdb
ipref_imdb=np.zeros((len(tbl2),len(tbl1)),dtype=np.int8)
pref_imdb=np.zeros((len(tbl2),len(tbl1)),dtype=np.int8)

# %%
def check_short_matching(COL1,COL2):
    rate = 0.0
    if str(COL1) == 'nan' or str(COL2) == 'nan' :
        return 0
    COL1 = str(COL1)
    COL2 = str(COL2)
    sw = (fuzz.SequenceMatcher(None,COL1, COL2).ratio())
    return sw #/(max(len(COL1),len(COL2))*1.0)

# %%
def check_match(st1,st2):
    str1 = np.array((st1.values).astype(str))
    str2 = np.array((st2.values).astype(str))
    ret = np.zeros((len(str1),len(str2)))
    for i in range(len(str1)):
        for j in range(len(str2)):
            ret[i,j] = check_short_matching(str1[i],str2[j])
    return numpy.average(ret)

# %%
dd = []
ret = []
value1 = []
value2 = []
index_i = 0
index_j = 0
for i in IMDB_DF_SAMPLE:
    dd = []
    for j in ROTTEN_TOMATOES_DF_SAMPLE:
        table1 = IMDB_DF_SAMPLE[i]
        table2 = ROTTEN_TOMATOES_DF_SAMPLE[j]
        value1 = (table1.values).astype(str)
        value2 = (table2.values).astype(str)
        #dd.append([ 100* (check_match(table1, table2)),i,j])
        #Pref[index_i,index_j] = 100 * (np.float(check_match(table1, table2)))
        print(i)
        index_j+=1
    index_i+=1
#print(index_j)
#check_match(table1, table2)
# Out:
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Id
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# Name
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# YearRange
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# ReleaseDate
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Director
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Creator
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Cast
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# Duration
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# RatingValue
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# ContentRating
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Genre
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Url
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
# Description
